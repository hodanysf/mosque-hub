# %%
import requests

# %%
API_KEY = 'AIzaSyA0np_qdbzooZ2asbRlO9MrQS_E4fPzknI'

# %%
import googlemaps

# Replace 'YOUR_API_KEY' with your actual API key
#API_KEY = 'YOUR_API_KEY'

# Create a client
gmaps = googlemaps.Client(key=API_KEY)

# %%
location = '43.6335025,-79.5240738'  # Example: Latitude and longitude of San Francisco, CA


radius = 6000 #meters

place_type = 'halal food'
places_result = gmaps.places_nearby(location=location, radius=radius, type=place_type)

for place in places_result['results']:
    print(place['name'], place['geometry']['location'])
# Out:
# Toronto {'lat': 43.653226, 'lng': -79.3831843}
# Old Mill Toronto Hotel {'lat': 43.6507434, 'lng': -79.4928485}
# Canadas Best Value Inn Toronto {'lat': 43.61027779999999, 'lng': -79.5526541}
# Super 5 Inn {'lat': 43.626207, 'lng': -79.56701199999999}
# Queensway Motel {'lat': 43.62786579999999, 'lng': -79.4969364}
# Deluxe Inn {'lat': 43.61865270000001, 'lng': -79.5393643}
# Mississauga Gate Inn {'lat': 43.62078279999999, 'lng': -79.5705445}
# Monte Carlo Inns - Toronto West Suites {'lat': 43.6197516, 'lng': -79.5721185}
# Cineplex Cinemas Queensway & VIP {'lat': 43.62103279999999, 'lng': -79.5152016}
# Best Buy {'lat': 43.6171686, 'lng': -79.5537239}
# GoodLife Fitness Etobicoke West Metro Centre {'lat': 43.62489590000001, 'lng': -79.5583849}
# The Rockpile {'lat': 43.6295808, 'lng': -79.5490453}
# The UPS Store {'lat': 43.64830120000001, 'lng': -79.5054936}
# Costco Wholesale {'lat': 43.6227444, 'lng': -79.5075391}
# The UPS Store {'lat': 43.6325328, 'lng': -79.55217789999999}
# The UPS Store {'lat': 43.615028, 'lng': -79.5574381}
# Sobeys Queensway {'lat': 43.63032, 'lng': -79.481343}
# Stay Inn Toronto {'lat': 43.61239270000001, 'lng': -79.5446259}
# Police Auctions Canada {'lat': 43.6361103, 'lng': -79.52338929999999}
# Mississauga {'lat': 43.5890452, 'lng': -79.6441198}

# %%
places_result["results"]
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 43.6079518, 'lng': -79.5809544},
#    'viewport': {'northeast': {'lat': 43.60925553029149,
#      'lng': -79.57965656970849},
#     'southwest': {'lat': 43.60655756970849, 'lng': -79.5823545302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_islam-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_islam_pinlet',
#   'name': 'Mississauga Muslim Community Center',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2448,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100547446356034528925">Ahmad Abuzaid</a>'],
#     'photo_reference': 'ATplDJZxWnHX6fd9yWrF3Jzom_wBWHOyPlqOTjRt5xT3WrAOTN-Lky5R1Pg09Pjn9ZaoME5OJ6VZfmAiIgMih75WX823OihR0yb9pSAmwxjDtXdNYJ5kBeks1qq3vDuM2SX4AiDIbsU1IOAJwx6z1MafoJWhM5YTDxw3_K3wi4fGb5gnS3nx',
#     'width': 3264}],
#   'place_id': 'ChIJTXYv4-xHK4gRBUFgEUwubR8',
#   'plus_code': {'compound_code': 'JC59+5J Mississauga, ON, Canada',
#    'global_code': '87M2JC59+5J'},
#   'rating': 4.8,
#   'reference': 'ChIJTXYv4-xHK4gRBUFgEUwubR8',
#   'scope': 'GOOGLE',
#   'types': ['mosque',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 362,
#   'vicinity': '2505 Dixie Road, Mississauga'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 43.60348399999999, 'lng': -79.5042532},
#    'viewport': {'northeast': {'lat': 43.60494353029149,
#      'lng': -79.50294996970848},
#     'southwest': {'lat': 43.60224556970849, 'lng': -79.5056479302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_islam-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_islam_pinlet',
#   'name': 'Bosnian Islamic Centre',
#   'photos': [{'height': 4608,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101392399064059606378">Nas</a>'],
#     'photo_reference': 'ATplDJaZdk8QMPzi_7H-RyXJaTaXCB5Ua6lElvCLK4kwMTUl5nN0PQRbpwYeyfS3Ep7j-KqFQZjjXvrnQPAwoIhBx7ME5ir3hp3bf4zED22RugW5H-_pm5Hdr2GmFqVmdKOj1NkKpbsSh9XiICbxD2A2kQd8Vr9YvqXprh4F7qOUt0UipjA-',
#     'width': 3456}],
#   'place_id': 'ChIJBe084s9JK4gRAGaRzkISCQo',
#   'plus_code': {'compound_code': 'JF3W+97 Etobicoke, Toronto, ON, Canada',
#    'global_code': '87M2JF3W+97'},
#   'rating': 4.8,
#   'reference': 'ChIJBe084s9JK4gRAGaRzkISCQo',
#   'scope': 'GOOGLE',
#   'types': ['mosque',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 265,
#   'vicinity': '75 Birmingham Street, Etobicoke'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 43.62064090000001, 'lng': -79.5500202},
#    'viewport': {'northeast': {'lat': 43.6218551802915,
#      'lng': -79.5485987197085},
#     'southwest': {'lat': 43.61915721970851, 'lng': -79.55129668029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_islam-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_islam_pinlet',
#   'name': 'Bosnian Islamic Assoc Gazi Husrev-Beg',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104137312781142398117">AbdulRaheem Siddiqui</a>'],
#     'photo_reference': 'ATplDJbX2YnepoiYkpwK33dDVXALk2mfr7A-CBVDdRS5qVbq77C3hsiDcuowwrsIlCiDqAzA1z1utpZlQSjwAGs31zFrpTwxt-E-pqcv0acmgaeDC8g_voq_YgZwF16tFm7S-sQQsk8Mkb_uZiedMMuou2MOY4aAIlZg_dLgfmMcnSHQEkeK',
#     'width': 3024}],
#   'place_id': 'ChIJwUfEzvw3K4gRLimQ0EhboEo',
#   'plus_code': {'compound_code': 'JCCX+7X Etobicoke, Toronto, ON, Canada',
#    'global_code': '87M2JCCX+7X'},
#   'rating': 4.9,
#   'reference': 'ChIJwUfEzvw3K4gRLimQ0EhboEo',
#   'scope': 'GOOGLE',
#   'types': ['mosque',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 514,
#   'vicinity': '122 North Queen Street, Etobicoke'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 43.66000409999999,
#     'lng': -79.48083729999999},
#    'viewport': {'northeast': {'lat': 43.6612983802915,
#      'lng': -79.47945391970849},
#     'southwest': {'lat': 43.6586004197085, 'lng': -79.48215188029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_islam-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_islam_pinlet',
#   'name': 'Albanian Mosque - Albanian Muslim Society of Toronto Inc.',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3264,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104882572014797438759">Zafir Yousuf</a>'],
#     'photo_reference': 'ATplDJYn3Li1ywuvsNtxZWLIob-RImy0yJpBA2dnyAlzws8mqse3zKV5HMjKtfeB9RC3U9FLsh639iJXKrRdSoXUUV9ym0DkuaTzzYo3OR5osHgO8QQ174NCQveSpaea_t3V6gb-Dnri6tnkZChBuyzhgsrZe9Izzi9SjTICMjwO09N_9yYE',
#     'width': 1836}],
#   'place_id': 'ChIJ535ympo2K4gRFXtjJJ2IWxI',
#   'plus_code': {'compound_code': 'MG69+2M Toronto, ON, Canada',
#    'global_code': '87M2MG69+2M'},
#   'rating': 4.1,
#   'reference': 'ChIJ535ympo2K4gRFXtjJJ2IWxI',
#   'scope': 'GOOGLE',
#   'types': ['mosque',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 79,
#   'vicinity': '564 Annette Street, Toronto'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 43.6250031, 'lng': -79.5871934},
#    'viewport': {'northeast': {'lat': 43.6263136302915,
#      'lng': -79.58590171970849},
#     'southwest': {'lat': 43.6236156697085, 'lng': -79.58859968029151}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_islam-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_islam_pinlet',
#   'name': 'Masjid Adam',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111553484505606594554">Hanan S.</a>'],
#     'photo_reference': 'ATplDJZjo6Qa7WVBPMd7NAXrmLwSgyLkjT41Dgb8YlLhBLo3MOcNUz6TCN8J-iuQHA3qdSQ39cqbTnJJ5jf-REscnm0PIFjAtG3s32r08OwFnk0V7a-fhlSCHiDbbkcMHYG3MbXroKG85b6r3BFzNvZDYabV3H5eWUne77REz2C7bJoFbrY4',
#     'width': 4032}],
#   'place_id': 'ChIJQ3yGc3Q4K4gR4a2SLD2BUos',
#   'plus_code': {'compound_code': 'JCG7+24 Mississauga, ON, Canada',
#    'global_code': '87M2JCG7+24'},
#   'rating': 4.6,
#   'reference': 'ChIJQ3yGc3Q4K4gR4a2SLD2BUos',
#   'scope': 'GOOGLE',
#   'types': ['mosque',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 175,
#   'vicinity': '1759 Bloor Street, Mississauga'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 43.6750632, 'lng': -79.47913319999999},
#    'viewport': {'northeast': {'lat': 43.6765609802915,
#      'lng': -79.47787156970848},
#     'southwest': {'lat': 43.6738630197085, 'lng': -79.48056953029149}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_islam-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_islam_pinlet',
#   'name': 'Nejashi Islamic Center',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1816,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117619220936083967974">Nejashi Islamic Center</a>'],
#     'photo_reference': 'ATplDJbZ-0fvseOT2fZMBT5AguEP48J4150oDDKtDKLqQYnipmZNzCzKnyfSy4npPZBIrixMUPlUxCCUvxLeehhEUgzZMHSyJEdpBlWKssRiPjI8vNVhOVL7kiIfWDP-CiG1XjlnHEelZagukWiZZL45lWg9SFiPt7eZ3ZlM8Q-2K9B7ynQ2',
#     'width': 4032}],
#   'place_id': 'ChIJJewwBaU2K4gRqNO7HmvtOuA',
#   'plus_code': {'compound_code': 'MGGC+28 York, Toronto, ON, Canada',
#    'global_code': '87M2MGGC+28'},
#   'rating': 4.6,
#   'reference': 'ChIJJewwBaU2K4gRqNO7HmvtOuA',
#   'scope': 'GOOGLE',
#   'types': ['mosque',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 23,
#   'vicinity': '171 McCormack Street, York'}]

# %%
origin = location
destination = 43.6079518,-79.5809544

# %%
distance_matrix = gmaps.distance_matrix(origin, destination)

# Extract the distance in meters
distance_in_meters = distance_matrix['rows'][0]['elements'][0]['distance']['value']

# Convert distance from meters to kilometers
distance_in_kilometers = distance_in_meters / 1000

# %%
distance_in_kilometers
# Out:
# 8.006

# %%
print(f"The distance between {origin} and {destination} is approximately {distance_in_kilometers:.2f} kilometers.")
# Out:
# The distance between 43.6335025,-79.5240738 and (43.6079518, -79.5809544) is approximately 8.01 kilometers.

# %%
info()
# Out:
# [{'masjid_name': 'Mississauga Muslim Community Center',
#   'location': {'lat': 43.6079518, 'lng': -79.5809544},
#   'url': 'https://mmcc-canada.org/',
#   'kilometers_away': 8.006},
#  {'masjid_name': 'Bosnian Islamic Centre',
#   'location': {'lat': 43.60348399999999, 'lng': -79.5042532},
#   'url': 'http://bictoronto.com/',
#   'kilometers_away': 4.204},
#  {'masjid_name': 'Bosnian Islamic Assoc Gazi Husrev-Beg',
#   'location': {'lat': 43.62064090000001, 'lng': -79.5500202},
#   'url': 'http://www.biaghb.com/',
#   'kilometers_away': 3.279},
#  {'masjid_name': 'Albanian Mosque - Albanian Muslim Society of Toronto Inc.',
#   'location': {'lat': 43.66000409999999, 'lng': -79.48083729999999},
#   'url': 'http://www.albmuslim.ca/',
#   'kilometers_away': 7.141},
#  {'masjid_name': 'Masjid Adam',
#   'location': {'lat': 43.6250031, 'lng': -79.5871934},
#   'url': 'http://www.masjidadam.com/',
#   'kilometers_away': 6.554},
#  {'masjid_name': 'Nejashi Islamic Center',
#   'location': {'lat': 43.6750632, 'lng': -79.47913319999999},
#   'url': 'http://www.nejashi.ca/',
#   'kilometers_away': 7.75}]

# %%
def masjids_nearby():
    lst = []
    radius = 6000 #meters
    place_type = 'mosque'

    places_result = gmaps.places_nearby(location=location, radius=radius, type=place_type)
    for place in places_result['results']:
        final = {}
        final["masjid_name"] = place['name']
        final["location"] = place['geometry']['location']

        place_details = gmaps.place(place["place_id"])
        if 'website' in place_details['result']:
            final["url"] = place_details['result']['website']
        else:
            final["url"] = ""

        distance_matrix = gmaps.distance_matrix(origin, final["location"])

        distance_in_meters = distance_matrix['rows'][0]['elements'][0]['distance']['value']

        distance_in_kilometers = distance_in_meters / 1000

        final["kilometers_away"] = distance_in_kilometers
        lst.append(final)
    return lst


def food_nearby():
    lst = []
    radius = 6000 #meters
    place_type = 'halal'

    places_result = gmaps.places_nearby(location=location, radius=radius, type=place_type)
    for place in places_result['results']:
        final = {}
        final["restaurant_name"] = place['name']
        final["location"] = place['geometry']['location']

        place_details = gmaps.place(place["place_id"])
        if 'website' in place_details['result']:
            final["url"] = place_details['result']['website']
        else:
            final["url"] = ""

        distance_matrix = gmaps.distance_matrix(origin, final["location"])

        distance_in_meters = distance_matrix['rows'][0]['elements'][0]['distance']['value']

        distance_in_kilometers = distance_in_meters / 1000

        final["kilometers_away"] = distance_in_kilometers
        lst.append(final)
    return lst

# %%
food_nearby()
# Out:
# [{'restaurant_name': 'Toronto',
#   'location': {'lat': 43.653226, 'lng': -79.3831843},
#   'url': 'http://www.toronto.ca/',
#   'kilometers_away': 15.528},
#  {'restaurant_name': 'Old Mill Toronto Hotel',
#   'location': {'lat': 43.6507434, 'lng': -79.4928485},
#   'url': 'https://oldmilltorontohotel.com/',
#   'kilometers_away': 4.41},
#  {'restaurant_name': 'Canadas Best Value Inn Toronto',
#   'location': {'lat': 43.61027779999999, 'lng': -79.5526541},
#   'url': 'http://www.canadasbestvalueinntoronto.com/',
#   'kilometers_away': 4.756},
#  {'restaurant_name': 'Super 5 Inn',
#   'location': {'lat': 43.626207, 'lng': -79.56701199999999},
#   'url': 'https://www.super5inntoronto.com/',
#   'kilometers_away': 4.868},
#  {'restaurant_name': 'Queensway Motel',
#   'location': {'lat': 43.62786579999999, 'lng': -79.4969364},
#   'url': 'http://www.queenswaymotel.com/',
#   'kilometers_away': 3.149},
#  {'restaurant_name': 'Deluxe Inn',
#   'location': {'lat': 43.61865270000001, 'lng': -79.5393643},
#   'url': 'http://www.deluxeinntoronto.com/',
#   'kilometers_away': 2.916},
#  {'restaurant_name': 'Mississauga Gate Inn',
#   'location': {'lat': 43.62078279999999, 'lng': -79.5705445},
#   'url': 'https://www.mississaugagateinn.com/',
#   'kilometers_away': 5.524},
#  {'restaurant_name': 'Monte Carlo Inns - Toronto West Suites',
#   'location': {'lat': 43.6197516, 'lng': -79.5721185},
#   'url': 'https://www.montecarloinns.com/toronto-west-suites',
#   'kilometers_away': 5.658},
#  {'restaurant_name': 'Cineplex Cinemas Queensway & VIP',
#   'location': {'lat': 43.62103279999999, 'lng': -79.5152016},
#   'url': 'https://www.cineplex.com/Theatre/cineplex-cinemas-queensway-and-vip?utm_source=google&utm_medium=organic&utm_campaign=local&utm_content=CPXQueenswayVIP',
#   'kilometers_away': 2.086},
#  {'restaurant_name': 'Best Buy',
#   'location': {'lat': 43.6171686, 'lng': -79.5537239},
#   'url': 'https://stores.bestbuy.ca/en-ca/on/etobicoke/167-north-queen-st',
#   'kilometers_away': 3.841},
#  {'restaurant_name': 'GoodLife Fitness Etobicoke West Metro Centre',
#   'location': {'lat': 43.62489590000001, 'lng': -79.5583849},
#   'url': 'https://www.goodlifefitness.com/clubs/club.183.html?utm_source=G&utm_medium=LPM&utm_campaign=GoodlifeFitness',
#   'kilometers_away': 5.529},
#  {'restaurant_name': 'The Rockpile',
#   'location': {'lat': 43.6295808, 'lng': -79.5490453},
#   'url': 'http://www.therockpile.ca/',
#   'kilometers_away': 3.407},
#  {'restaurant_name': 'The UPS Store',
#   'location': {'lat': 43.64830120000001, 'lng': -79.5054936},
#   'url': 'http://theupsstore.ca/55',
#   'kilometers_away': 3.102},
#  {'restaurant_name': 'Costco Wholesale',
#   'location': {'lat': 43.6227444, 'lng': -79.5075391},
#   'url': 'https://www.costco.ca/warehouse-locations/etobicoke-ON-524.html?utm_term=KW&utm_campaign=Homepage&utm_medium=GMB&utm_source=Google&utm_content=Link',
#   'kilometers_away': 2.376},
#  {'restaurant_name': 'The UPS Store',
#   'location': {'lat': 43.6325328, 'lng': -79.55217789999999},
#   'url': 'http://theupsstore.ca/176',
#   'kilometers_away': 3.696},
#  {'restaurant_name': 'The UPS Store',
#   'location': {'lat': 43.615028, 'lng': -79.5574381},
#   'url': 'http://theupsstore.ca/3',
#   'kilometers_away': 4.227},
#  {'restaurant_name': 'Sobeys Queensway',
#   'location': {'lat': 43.63032, 'lng': -79.481343},
#   'url': 'http://www.sobeys.com/en/stores/sobeys-queensway?utm_source=G&utm_medium=lpm&utm_campaign=Sobeys',
#   'kilometers_away': 4.503},
#  {'restaurant_name': 'Stay Inn Toronto',
#   'location': {'lat': 43.61239270000001, 'lng': -79.5446259},
#   'url': 'http://www.stayinnsuites.ca/',
#   'kilometers_away': 4.124},
#  {'restaurant_name': 'Police Auctions Canada',
#   'location': {'lat': 43.6361103, 'lng': -79.52338929999999},
#   'url': 'https://www.policeauctionscanada.com/',
#   'kilometers_away': 0.989},
#  {'restaurant_name': 'Mississauga',
#   'location': {'lat': 43.5890452, 'lng': -79.6441198},
#   'url': 'http://www.mississauga.ca/portal/home',
#   'kilometers_away': 15.801}]
